# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('../data/위험성 평가 정보_2021년.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11304 entries, 0 to 11303
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ﻿ACDNT_RISK_ASM_UQNUM     11304 non-null  int64
#  1   ACDNT_RISK_ASM_NO         11304 non-null  int64
#  2   PIPE_NO                   11304 non-null  int64
#  3   CO_INFO                   11304 non-null  object
#  4   ACDNT_TYPE                11304 non-null  object
#  5   ACDNT_DMGE_TYPE           11304 non-null  object
#  6   DMGE_ARA_CRTR_DGDGR       11304 non-null  float64
#  7   DMGE_ARA_CRTR_DGDGR_RANK  5652 non-null   object
#  8   DPRS_CRTR_DMGE_FQ         11304 non-null  float64
#  9   DPRS_CRTR_DMGE_SCALE      11304 non-null  int64
#  10  DPRS_CRTR_DGDGR           11304 non-null  float64
#  11  DPRS_CRTR_DGDGR_RANK      5652 non-null   object
#  12  PIPE_DIA                  11304 non-null  int64
# ...

# %%
df
# Out:
#        ﻿ACDNT_RISK_ASM_UQNUM  ACDNT_RISK_ASM_NO  PIPE_NO CO_INFO ACDNT_TYPE  \
# 0                          1                  1      110     회사1    rupture
# 1                          2                  1      110     회사1    rupture
# 2                          3                  1      110     회사1    rupture
# 3                          4                  1      110     회사1       hole
# 4                          5                  1      110     회사1       hole
# ...                      ...                ...      ...     ...        ...
# 11299                  11300                110   500682    회사10       hole
# 11300                  11301                110   500682    회사10    pinhole
# 11301                  11302                110   500682    회사10    rupture
# 11302                  11303                110   500682    회사10       hole
# 11303                  11304                110   500682    회사10    pinhole
#
# ...

# %%
df=df.rename(columns={'ACDNT_DMGE_TYPE':'사고피해유형'})

# %%
df=df.rename(columns={'ACDNT_TYPE':'사고유형'})

# %%
df
# Out:
#        ﻿ACDNT_RISK_ASM_UQNUM  ACDNT_RISK_ASM_NO  PIPE_NO CO_INFO     사고유형  \
# 0                          1                  1      110     회사1  rupture
# 1                          2                  1      110     회사1  rupture
# 2                          3                  1      110     회사1  rupture
# 3                          4                  1      110     회사1     hole
# 4                          5                  1      110     회사1     hole
# ...                      ...                ...      ...     ...      ...
# 11299                  11300                110   500682    회사10     hole
# 11300                  11301                110   500682    회사10  pinhole
# 11301                  11302                110   500682    회사10  rupture
# 11302                  11303                110   500682    회사10     hole
# 11303                  11304                110   500682    회사10  pinhole
#
#           사고피해유형  DMGE_ARA_CRTR_DGDGR DMGE_ARA_CRTR_DGDGR_RANK  \
# ...

# %%
df.describe()
# Out:
#        ﻿ACDNT_RISK_ASM_UQNUM  ACDNT_RISK_ASM_NO        PIPE_NO  \
# count           11304.000000       11304.000000   11304.000000
# mean             5652.500000          47.664544  430029.527601
# std              3263.328056          35.522296  358220.813802
# min                 1.000000           1.000000       0.000000
# 25%              2826.750000          17.000000     836.000000
# 50%              5652.500000          41.000000  500305.000000
# 75%              8478.250000          75.000000  820203.000000
# max             11304.000000         150.000000  830253.000000
#
#        DMGE_ARA_CRTR_DGDGR  DPRS_CRTR_DMGE_FQ  DPRS_CRTR_DMGE_SCALE  \
# count         11304.000000       1.130400e+04          11304.000000
# mean              0.251931       9.489381e-07              2.200991
# std               1.586487       3.661475e-06             10.952348
# min               0.000000       0.000000e+00              0.000000
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15848\4020668464.py in <module>
# ----> 1 df_type=df.groupby('사고피해유형')('사고유형').sum()
#
# TypeError: 'DataFrameGroupBy' object is not callable
